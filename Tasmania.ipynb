# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Tasmania_Data.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#        'x0'      'x1'      'x2'    'x3'      'x4'      'x5'      'x6'  \
# 0  427.0737  155.1636  476.0661  5.7677  255.5230  410.5835  516.3158
# 1  427.4820  147.4593  474.9960  9.5407  258.2593  404.2589  524.3422
# 2  423.7709  155.9451  470.8182  4.0438  253.8868  390.2231  509.0224
# 3  431.8288  146.6720  466.1145  7.0164  261.3787  408.9941  521.9852
# 4  437.7897  141.3579  474.3819  4.3434  256.5644  393.0113  516.1617
#
#       'x7'     'x8'      'x9'  ...         'p7'        'p8'        'p9'  \
# 0  47.4719  75.7125  463.0522  ...  100328.8932  79696.1132  90093.0925
# 1  44.4009  70.4385  468.8828  ...   98879.6861  82893.9171  89158.6518
# 2  50.7996  72.8076  463.4203  ...  100504.0370  81572.7820  89932.3496
# 3  44.0360  77.5854  450.5736  ...   99857.6062  82267.0302  88657.7954
# 4  52.4880  66.1179  457.0365  ...   99953.9882  80579.2854  88819.3409
#
#         'p10'        'p11'       'p12'       'p13'        'p14'       'p15'  \
# 0  79395.6995  100893.8537  91116.6415  98560.6700   99789.2341  78199.7899
# 1  80356.5067  100927.1007  89760.5631  97828.2206   99214.7876  79108.3094
# 2  80588.3130  100977.1693  90274.1347  97757.2251   99333.6857  79691.2458
# 3  79139.2437  100480.0554  91102.1702  98224.0435  100672.3076  78387.9296
# 4  80145.6969  100693.3759  89663.6079  97947.9575  100924.1871  80104.7240
#
#          'sum'
# 0  1480707.346
# 1  1479133.940
# 2  1475814.243
# 3  1484052.684
# 4  1479350.362
#
# [5 rows x 49 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#            'x0'      'x1'      'x2'      'x3'      'x4'      'x5'      'x6'  \
# 'x0'   1.000000 -0.013194 -0.123853 -0.096225 -0.149830  0.051837  0.007318
# 'x1'  -0.013194  1.000000 -0.107232  0.025016  0.043747  0.057597 -0.024376
# 'x2'  -0.123853 -0.107232  1.000000  0.042905  0.052562 -0.017024  0.020728
# 'x3'  -0.096225  0.025016  0.042905  1.000000  0.147254 -0.071566  0.020196
# 'x4'  -0.149830  0.043747  0.052562  0.147254  1.000000 -0.065420 -0.013103
# 'x5'   0.051837  0.057597 -0.017024 -0.071566 -0.065420  1.000000  0.046734
# 'x6'   0.007318 -0.024376  0.020728  0.020196 -0.013103  0.046734  1.000000
# 'x7'   0.024086 -0.114094 -0.030494 -0.078508 -0.079067 -0.089910 -0.086836
# 'x8'   0.101234 -0.098866 -0.138068 -0.024864 -0.070555  0.004394 -0.035113
# 'x9'  -0.039929  0.005338  0.031584 -0.051101 -0.027683 -0.071704 -0.023976
# 'x10' -0.136847  0.081980 -0.185357 -0.051926  0.030334 -0.069725 -0.108112
# 'x11' -0.154409 -0.015409 -0.073253  0.037446  0.043565 -0.065132 -0.093008
# 'x12' -0.034851  0.010487 -0.029972 -0.044180 -0.104449 -0.064799 -0.075100
# 'p14' -0.015752 -0.137304  0.135206 -0.022021 -0.060190 -0.095177 -0.017527
# 'p15' -0.016915 -0.004049 -0.012238 -0.107316  0.001240 -0.078056 -0.016862
# 'sum' -0.051351 -0.103755  0.143548 -0.081862  0.084646  0.001279 -0.050477
#
#            'x7'      'x8'      'x9'  ...      'p7'      'p8'      'p9'  \
# 'x0'   0.024086  0.101234 -0.039929  ... -0.027194  0.008357 -0.021730
# 'x1'  -0.114094 -0.098866  0.005338  ... -0.114525 -0.021130 -0.046195
# 'x2'  -0.030494 -0.138068  0.031584  ...  0.142520 -0.047011 -0.066098
# 'x3'  -0.078508 -0.024864 -0.051101  ... -0.078463 -0.006495 -0.081594
# 'x4'  -0.079067 -0.070555 -0.027683  ... -0.011176 -0.008717  0.007505
# 'x5'  -0.089910  0.004394 -0.071704  ... -0.000061 -0.041772  0.005461
# 'x6'  -0.086836 -0.035113 -0.023976  ... -0.096449 -0.085603 -0.083886
# 'x7'   1.000000  0.091817 -0.163148  ...  0.309628 -0.040930 -0.040937
# 'x8'   0.091817  1.000000 -0.192651  ... -0.056892  0.342393 -0.044033
# 'x9'  -0.163148 -0.192651  1.000000  ... -0.024710 -0.053705  0.260072
# 'x10' -0.023158 -0.021137  0.010502  ... -0.079826 -0.028619  0.055512
# 'x11'  0.063651  0.016543 -0.130482  ...  0.034168 -0.019442 -0.004549
# 'x12' -0.074218  0.022219  0.024756  ... -0.033745 -0.019263 -0.040017
# 'x13' -0.111435 -0.025161  0.047783  ... -0.083712  0.048975  0.030802
# 'x14' -0.039648 -0.096784  0.011658  ... -0.009599 -0.061798  0.017256
# 'x15'  0.189599 -0.086600 -0.094173  ...  0.072746 -0.018169  0.019726
# 'y0'   0.031876 -0.084561 -0.060568  ... -0.002506 -0.049691 -0.048820
# 'y1'  -0.036792  0.005944  0.073632  ...  0.016325  0.028453 -0.042369
# 'y2'   0.017227  0.060444  0.013734  ... -0.117530 -0.007454 -0.022466
# 'y3'   0.007096  0.090984 -0.065106  ...  0.027884 -0.037525 -0.028149
# 'y4'   0.040287 -0.031705  0.001360  ... -0.020223 -0.025922 -0.015644
# 'y5'   0.039887 -0.008518  0.059508  ... -0.038402 -0.000650 -0.071405
# 'y6'   0.033944  0.022575 -0.019608  ...  0.060338  0.014250 -0.024257
# 'y7'  -0.265938 -0.104709  0.109774  ...  0.464202 -0.012899 -0.015169
# 'y8'  -0.138443 -0.174738  0.077133  ... -0.081752  0.488964  0.012747
# 'y9'   0.079696  0.090414 -0.281123  ... -0.127741 -0.020225  0.473673
# 'y10'  0.066413  0.020302  0.008928  ...  0.062638 -0.019206 -0.050100
# 'y11' -0.008506 -0.096335  0.148608  ... -0.076312 -0.150749  0.037512
# 'y12'  0.080801  0.012288 -0.152305  ... -0.037342 -0.014337 -0.105718
# 'y13'  0.101603  0.022457 -0.106781  ... -0.064897 -0.104651 -0.043570
# 'y14'  0.048780 -0.017017  0.060342  ... -0.011515 -0.007476  0.010248
# 'y15' -0.086222  0.011013  0.049879  ... -0.148399 -0.000043  0.007945
# 'p0'   0.017787 -0.026666 -0.090245  ...  0.112686  0.030300  0.022926
# 'p1'  -0.118229 -0.131714  0.072258  ...  0.031105  0.049892  0.017675
# 'p2'  -0.071585 -0.099457  0.063056  ...  0.114739  0.023822 -0.002340
# 'p3'  -0.091360  0.013136 -0.066119  ...  0.081476  0.025304 -0.013898
# 'p4'  -0.081393 -0.081685 -0.031693  ...  0.049822  0.031748  0.040154
# 'p5'  -0.016562  0.004793 -0.013649  ...  0.061989  0.016153  0.010873
# 'p6'  -0.069416 -0.018984 -0.068711  ...  0.086308  0.048030  0.029169
# 'p7'   0.309628 -0.056892 -0.024710  ...  1.000000  0.022069  0.002230
# 'p8'  -0.040930  0.342393 -0.053705  ...  0.022069  1.000000  0.023667
# 'p9'  -0.040937 -0.044033  0.260072  ...  0.002230  0.023667  1.000000
# 'p10' -0.002535 -0.062036 -0.036251  ...  0.118013  0.045188  0.026022
# 'p11'  0.031721 -0.037384 -0.011981  ...  0.053668 -0.044890  0.071770
# 'p12'  0.007233  0.009911 -0.113971  ...  0.034171  0.069637 -0.041886
# 'p13' -0.005042  0.006919 -0.029118  ...  0.002827  0.028836  0.087626
# 'p14' -0.005322 -0.106059  0.013136  ...  0.128196  0.041325  0.068185
# 'p15'  0.049248 -0.032580 -0.058427  ...  0.048921  0.060521  0.089738
# 'sum' -0.023373 -0.065130 -0.037915  ...  0.390205  0.288012  0.279632
#
#           'p10'     'p11'     'p12'     'p13'     'p14'     'p15'     'sum'
# 'x0'  -0.139977 -0.115126 -0.043521  0.068673 -0.015752 -0.016915 -0.051351
# 'x1'  -0.012458 -0.127251 -0.046719 -0.038051 -0.137304 -0.004049 -0.103755
# 'x2'   0.133869 -0.023883 -0.021719 -0.048651  0.135206 -0.012238  0.143548
# 'x3'   0.009586 -0.109638  0.011888 -0.148662 -0.022021 -0.107316 -0.081862
# 'x4'   0.058962  0.021737  0.019019 -0.045163 -0.060190  0.001240  0.084646
# 'x5'  -0.050349 -0.063007 -0.016643  0.079689 -0.095177 -0.078056  0.001279
# 'x6'  -0.062160 -0.057657 -0.031151 -0.009166 -0.017527 -0.016862 -0.050477
# 'x7'  -0.002535  0.031721  0.007233 -0.005042 -0.005322  0.049248 -0.023373
# 'x8'  -0.062036 -0.037384  0.009911  0.006919 -0.106059 -0.032580 -0.065130
# 'x9'  -0.036251 -0.011981 -0.113971 -0.029118  0.013136 -0.058427 -0.037915
# 'x10'  0.259677  0.008415 -0.022248 -0.023712 -0.094192 -0.010950 -0.081331
# 'x11'  0.042361  0.435286 -0.019231 -0.127634 -0.079073  0.040647  0.090406
# 'x12' -0.014154  0.029501  0.256795 -0.096045 -0.072435 -0.076998 -0.058303
# 'x13' -0.072825 -0.014607 -0.047378  0.343586 -0.063017  0.044399  0.015352
# 'p15'  0.113693  0.048678  0.007210  0.029384  0.077285  1.000000  0.362503
# 'sum'  0.366425  0.256077  0.223605  0.239794  0.365607  0.362503  1.000000
#
# [49 rows x 49 columns]

# %%
vars = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15']
vars = ["'" + x + "'" for x in vars]

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

def get_metrics(xtest, ytest, ypredicted, model):
    print(f'R square: {model.score(xtest, ytest)}')
    print(f'RMSE: {rmse(ypredicted, ytest)}')

# %%
class PreparedData:
    def __init__(self, df, name):
        self.x = df[vars]
        self.y = df["'sum'"]
        self.name = name

data = pd.read_csv("Tasmania_Data.csv")
df = pd.DataFrame(data)
tasmania = PreparedData(df, "tasmania")

data = pd.read_csv("Adelaide_Data.csv")
df = pd.DataFrame(data)
adelaide = PreparedData(df, "adelaide")

data = pd.read_csv("Perth_Data.csv")
df = pd.DataFrame(data)
perth = PreparedData(df, "perth")

data = pd.read_csv("Sydney_Data.csv")
df = pd.DataFrame(data)
sydney = PreparedData(df, "sydney")

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Simple linear regression

# %%
x = df[vars]
y = df["'sum'"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 42)

model = LinearRegression()
model.fit(x_train, y_train)

y_predicted = model.predict(x_test)

plt.scatter(y_predicted, y_test)

# %% [markdown]
# metrics

# %%
get_metrics(x_test, y_test, y_predicted, model)
# Out:
# R square: 0.13221150248115943
# RMSE: 48249.56382484495

# %% [markdown]
# # Polynominal Features Linear Regression

# %%
x = df[vars].values.reshape(-1, len(vars))
y = df["'sum'"].values.reshape(-1)

poly = PolynomialFeatures(2, include_bias = False)
x = poly.fit_transform(x)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=43)
    
model = LinearRegression()
model.fit(X_train, y_train)

y_pred_test = model.predict(X_test)
plt.scatter(y_pred_test, y_test)

print(f'r2 score: {model.score(X_test, y_test)}')
# Out:
# r2 score: 0.8184271814338366

# %% [markdown]
# metrics

# %%
get_metrics(X_test, y_test, y_pred_test, model)
# Out:
# R square: 0.8184271814338366
# RMSE: 22289.403663838642

# %% [markdown]
# # xgboost

# %%
from xgboost import XGBRegressor

# %%
xgbr = XGBRegressor(verbosity=0)

# %%
model = xgbr.fit(X_train, y_train)

# %%
y_predict = model.predict(X_test)
mse_xgb = mean_squared_error(y_test, y_predict)

plt.scatter(y_pred_test, y_test)
plt.ylabel("y true")
plt.xlabel("y predicted")
# Out:
# Text(0.5, 0, 'y predicted')

# %% [markdown]
# Metrics

# %%
get_metrics(X_test, y_test, y_predict, model)
# Out:
# R square: 0.8286262385907772
# RMSE: 21654.352208032942

# %% [markdown]
# # light gbm
